# %% [markdown]
# # Q3-3.ディスプレイテキストの表示2

# %% [markdown]
# ## 問題
# **Q3-3.M5のディスプレイに"あか", "きいろ", "あお"と縦に3つ並べて表示してみましょう。**
# 文字の色はそれぞれの字と同じ色（"あか"なら赤色）にしましょう。

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# akari_clientをインポートする。
from akari_client import AkariClient
# 色を指定する際に使うColors,Colorのインポート
from akari_client.color import Colors, Color
# 位置を指定する際に使うPositionsのインポート
from akari_client.position import Positions
# sleep関数を使うためにtimeのライブラリをインポートする。
import time

# AkariClient、m5stackのインスタンスを取得する
akari = AkariClient()
m5 = akari.m5stack

m5.set_display_color(Colors.WHITE)

### ここから問題  ###
# "あか"を表示
# textは"あか"
text = """(表示したい文字を入力)"""
# 左右表示位置は真中揃え
pos_x = Positions.CENTER
# 上下表示位置は30
pos_y = 30
# 文字サイズは5
size = 5
# 文字色は赤
text_color = """(表示したい色を入力)"""
# 背景色は白
back_color = Colors.WHITE
# 最初の１つ目は背景をリセットする
refresh = """(TrueかFalseを入力)"""
# set_display_textを実行
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)

# "きいろ"を表示
# textは"きいろ"
text = """(表示したい文字を入力)"""
# 左右表示位置は真中揃え
pos_x = Positions.CENTER
# 上下表示位置は90
pos_y = 90
# 文字サイズは5
size = 5
# 文字色は黄色
text_color = """(表示したい色を入力)"""
# 背景色は白
back_color = Colors.WHITE
# 前の文字を消さないために、背景はリセットしない。
refresh = """(TrueかFalseを入力)"""
# set_display_textを実行
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)

# "あお"を表示
# textは"あお"
text = """(表示したい文字を入力)"""
# 左右表示位置は真中揃え
pos_x = -999
# 上下表示位置は150
pos_y = 150
# 文字サイズは5
size = 5
# 文字色は青
text_color = """(表示したい色を入力)"""
# 背景色は白
back_color = Colors.WHITE
# 前の文字を消さないために、背景はリセットしない。
refresh = """(TrueかFalseを入力)"""
# set_display_textを実行
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)
### ここまで  ###

# %% [markdown]
# ### 動作イメージ

# %%
from IPython.display import Image
Image('image/q3-3.jpg')

# %% [markdown]
# ### ヒント
# [Q3-2](q3-2_display_text.ipynb)同様、 _set_display_text()_ を使っていきます。
#
# 今回は _refresh=_ 引数の穴埋めをします。
# refreshを True にするとset_display_textをする前に画面全体を現在の背景色で更新します。defaultは True です。
# Falseにすると前回の表示を残したまま文字を描画することができます。
# これまで表示していた文字や画像を消さずに、続けて表示したい場合は、refresh=を False にします。
#
# 今回は最初の"あか"の時は画面を消して新しく表示し、残りの"きいろ", "あお"の時は消さずに続けて表示していくようにしましょう。
#
# 下記のセルを実行すると使い方の例が見られます。

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# akari_clientをインポートする。
from akari_client import AkariClient
# 色を指定する際に使うColors,Colorのインポート
from akari_client.color import Colors, Color
# 位置を指定する際に使うPositionsのインポート
from akari_client.position import Positions
# sleep関数を使うためにtimeのライブラリをインポートする。
import time

# AkariClient、m5stackのインスタンスを取得する
akari = AkariClient()
m5 = akari.m5stack

m5.set_display_color(Colors.WHITE)

text = "新規"
pos_x = Positions.CENTER
pos_y = 30
size = 4
text_color = Colors.BLACK
back_color = Colors.WHITE
refresh = True
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)

text = "上書きしない"
pos_x = Positions.CENTER
pos_y = 150
size = 4
text_color = Colors.RED
back_color = Colors.WHITE
refresh = False
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )

# %% [markdown]
# text_color,back_colorを指定することで文字色と文字の背景色を変更できます。
#
# 色はset_display_colorと同様RGB値を指定する方法と、Colorsクラスから色名を指定する方法の両方を使うことができます。
# それぞれテキストの表示色に異なる色が指定されています。
# [akari_manual](https://akari-docs.vbcpp.net/source/spec/soft_base.html#akari_client.color.Colors)から指定の色を選んで穴埋めしてください。

# %% [markdown]
# 完成したら実行してみましょう。
# M5のディスプレイに「あか」「きいろ」「あお」とそれぞれの色で表示されれば成功です。

# %% [markdown]
# ## 回答と解説
# 以下は回答例と解説です。動作が正しければ、これと同じでなくても問題ありません。

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# akari_clientをインポートする。
from akari_client import AkariClient
# 色を指定する際に使うColors,Colorのインポート
from akari_client.color import Colors
# 位置を指定する際に使うPositionsのインポート
from akari_client.position import Positions
# sleep関数を使うためにtimeのライブラリをインポートする。
import time

# AkariClient、m5stackのインスタンスを取得する
akari = AkariClient()
m5 = akari.m5stack

m5.set_display_color(Colors.WHITE)

### ここから問題  ###
# "あか"を表示
# textは"あか"
text = "あか"
# 左右表示位置は真中揃え
pos_x = Positions.CENTER
# 上下表示位置は30
pos_y = 30
# 文字サイズは5
size = 5
# 文字色は赤
text_color = Colors.RED
# 背景色は白
back_color = Colors.WHITE
# 最初の１つ目は背景をリセットする
refresh = True
# set_display_textを実行
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)

# "きいろ"を表示
# textは"きいろ"
text = "きいろ"
# 左右表示位置は真中揃え
pos_x = Positions.CENTER
# 上下表示位置は90
pos_y = 90
# 文字サイズは5
size = 5
# 文字色は黄色
text_color = Colors.YELLOW
# 背景色は白
back_color = Colors.WHITE
# 前の文字を消さないために、背景はリセットしない。
refresh = False
# set_display_textを実行
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)

# "あお"を表示
# textは"あお"
text = "あお"
# 左右表示位置は真中揃え
pos_x = Positions.CENTER
# 上下表示位置は150
pos_y = 150
# 文字サイズは5
size = 5
# 文字色は青
text_color = Colors.BLUE
# 背景色は白
back_color = Colors.WHITE
# 前の文字を消さないために、背景はリセットしない。
refresh = False
# set_display_textを実行
m5.set_display_text(
    text=text,
    pos_x=pos_x,
    pos_y=pos_y,
    size=size,
    text_color=text_color,
    back_color=back_color,
    refresh=refresh
    )
# 0.5秒停止
time.sleep(0.5)
### ここまで  ###

# %% [markdown]
# #### 22行目:
# ```python
# text = "あか"
# ```
# textの引数には、str形式で出力したい文字列を与えます。今回は"あか"です。
#
# #### 30行目:
# ```python
# text_color = Colors.RED
# ```
# 文字の色は表示するテキストと同じ赤を指定します。
#
# #### 34行目:
# ```python
# refresh = True
# ```
# 最初の文字列を表示するため、一旦画面表示をリセットします。
# refreshをTrueにすることで、画面をback_colorで指定した色(今回は白)でリセットした上で文字が表示されます。
#
# #### 50行目:
# ```python
# text = "きいろ"
# ```
# 次は"きいろ"です。
#
# #### 58行目:
# ```python
# text_color = Colors.YELLOW
# ```
# 同じく文字色は黄色にします。
#
# #### 62行目:
# ```python
# refresh = False
# ```
# 前の"あか"を消さずに表示したいため、refresh=Falseにします。
#
# #### 78行目:
# ```python
# text = "あお"
# ```
# 最後は"あお"です。
#
# #### 86行目:
# ```python
# text_color = Colors.BLUE
# ```
# 文字色は青にします。
#
# #### 90行目:
# ```python
# refresh = False
# ```
# 同じく、前の文字を残すため、字列を表示するため、refresh=Falseにします。

# %% [markdown]
# ## 最後に
# これでQ3-3は終了です。次は、テキスト表示を使って気圧計をつくってみましょう。

# %% [markdown]
# [Q3-4へ](q3-4_pressure_sensor.ipynb)
